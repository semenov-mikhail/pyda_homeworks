# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга"

# %% [markdown]
# ## Обязательная часть

# %% [markdown]
# Вам необходимо написать функцию, которая будет основана на **поиске** по сайту [habr.com](https://habr.com/ru/search/).
# Функция в качестве параметра должна принимать **список** запросов для поиска (например, `['python', 'анализ данных']`) и на основе материалов, попавших в результаты поиска по **каждому** запросу, возвращать датафрейм вида:
#
# ```
# <дата> - <заголовок> - <ссылка на материал>
# ```
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
import pandas as pd

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import time

# %%
def get_habr_articles(query):
    habr_articles = pd.DataFrame()
    url = 'https://habr.com/ru/search/'
    params = {
        'q': query
    }
    res = requests.get(url, params)
    time.sleep(0.3)
    soup = BeautifulSoup(res.text)
    articles = soup.find_all('article', class_='tm-articles-list__item')
    for article in articles:
            date = pd.to_datetime(article.find('time').get('title'))
            title = article.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2').text
            link = article.find('a', class_='tm-article-snippet__title-link').get('href')
            row = {'date': date, 'title': title, 'link': 'https://habr.com' + link}
            habr_articles = pd.concat([habr_articles, pd.DataFrame([row])])
    return habr_articles.drop_duplicates().reset_index(drop=True)

res = get_habr_articles(['python', 'анализ данных'])
res
# Out:
#                   date                                              title  \
# 0  2021-12-10 13:15:00  Интенсив для повышения квалификации: как испол...
# 1  2017-06-27 13:51:00  Использование Python и Excel для обработки и а...
# 2  2017-06-30 10:52:00  Использование Python и Excel для обработки и а...
# 3  2022-06-09 21:30:00  Шаблон новичка на пути PANDAS в искусстве анал...
# 4  2021-05-06 06:01:00      Python, исследование данных и выборы: часть 3
# 5  2020-09-22 16:43:00  Напишем и поймем Decision Tree на Python с нул...
# 6  2021-10-18 15:08:00  AI Journey Contest 2021: какие задачи мы подго...
# 7  2014-06-30 23:06:00  Обзор наиболее интересных материалов по анализ...
# 8  2014-11-23 16:49:00  Обзор наиболее интересных материалов по анализ...
# 9  2015-01-18 18:02:00  Обзор наиболее интересных материалов по анализ...
# 10 2014-09-14 19:54:00  Обзор наиболее интересных материалов по анализ...
# 11 2014-08-11 10:47:00  Обзор наиболее интересных материалов по анализ...
# 12 2015-02-01 15:55:00  Обзор наиболее интересных материалов по анализ...
# 13 2014-06-18 15:19:00  Обзор наиболее интересных материалов по анализ...
# 14 2014-07-28 13:10:00  Обзор наиболее интересных материалов по анализ...
# 15 2017-10-02 10:56:00  3 кейса применения анализа данных в сфере недв...
# 16 2017-10-23 01:42:00  «4 свадьбы и одни похороны» или линейная регре...
# 17 2022-03-04 19:00:00        Основы теории вероятностей с помощью Python
# 18 2017-09-04 10:50:00   Анализируя криптовалютные рынки с помощью Python
# 19 2015-07-24 11:20:00                  R и Python — достойные соперники?
#
#                                                  link
# 0   https://habr.com/ru/company/netologyru/news/t/...
# 1       https://habr.com/ru/company/otus/blog/331746/
# 2       https://habr.com/ru/company/otus/blog/331998/
# 3                    https://habr.com/ru/post/670668/
# 4                    https://habr.com/ru/post/556042/
# 5                    https://habr.com/ru/post/520204/
# 6   https://habr.com/ru/company/sbercloud/news/t/5...
# 7                    https://habr.com/ru/post/228187/
# 8                    https://habr.com/ru/post/243967/
# 9                    https://habr.com/ru/post/248165/
# 10                   https://habr.com/ru/post/236757/
# 11                   https://habr.com/ru/post/232879/
# 12                   https://habr.com/ru/post/249415/
# 13                   https://habr.com/ru/post/226641/
# 14                   https://habr.com/ru/post/231323/
# 15  https://habr.com/ru/company/newprolab/blog/339...
# 16                   https://habr.com/ru/post/340698/
# 17                   https://habr.com/ru/post/654407/
# 18     https://habr.com/ru/company/wirex/blog/406363/
# 19     https://habr.com/ru/company/piter/blog/263457/

# %% [markdown]
# ## Дополнительная часть (необязательная)

# %% [markdown]
# Функция из обязательной части задания должна быть расширена следующим образом:
# - кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента `4` необходимо получить материалы с первых 4 страниц результатов;
# - в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# ```
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>
# ```

# %%
def get_habr_articles(query, num_of_scrap_page=1):
    habr_articles = pd.DataFrame()
    url = 'https://habr.com/ru/search/'
    params = {
        'q': query
    }
    for i in range(1, num_of_scrap_page+1):
        res = requests.get(url+'page'+str(i), params)
        soup = BeautifulSoup(res.text)
        time.sleep(0.3)
        articles = soup.find_all('article', class_='tm-articles-list__item')
        
        for article in articles:
                date = pd.to_datetime(article.find('time').get('title'))
                title = article.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2').text
                link = article.find('a', class_='tm-article-snippet__title-link').get('href')
                req = requests.get('https://habr.com' + link).text
                soup_full_articles = BeautifulSoup(req)
                time.sleep(0.3)
                full_text = soup_full_articles.find('div', class_=['article-formatted-body article-formatted-body article-formatted-body_version-2', 'article-formatted-body article-formatted-body article-formatted-body_version-1', 'tm-expired-company']).text.strip()
                likes = soup_full_articles.find('span', class_=['tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating', 'tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_appearance-article tm-votes-meter__value_rating', 'tm-expired-company']).text.strip(' +')
                row = {'date': date, 'title': title, 'link': 'https://habr.com' + link, 'text': full_text, 'num of likes': likes}
                habr_articles = pd.concat([habr_articles, pd.DataFrame([row])])

    return habr_articles.drop_duplicates().reset_index(drop=True)

res = get_habr_articles(['python', 'анализ данных'], 4)
res
# Out:
#                   date                                              title  \
# 0  2021-12-10 13:15:00  Интенсив для повышения квалификации: как испол...
# 1  2017-06-27 13:51:00  Использование Python и Excel для обработки и а...
# 2  2017-06-30 10:52:00  Использование Python и Excel для обработки и а...
# 3  2022-06-09 21:30:00  Шаблон новичка на пути PANDAS в искусстве анал...
# 4  2021-05-06 06:01:00      Python, исследование данных и выборы: часть 3
# ..                 ...                                                ...
# 75 2020-05-12 13:52:00          Внутри виртуальной машины Python. Часть 1
# 76 2020-05-19 11:07:00  Как построить диаграмму Венна с 50 кругами? Ви...
# 77 2020-08-10 13:28:00  Алгоритм ранжирования сегментов речной сети с ...
# 78 2020-11-03 18:52:00  Развертывание интерактивных визуализаций данны...
# 79 2021-04-04 12:12:00          Все важные фичи и изменения в Python 3.10
#
#                                                  link  \
# 0   https://habr.com/ru/company/netologyru/news/t/...
# 1       https://habr.com/ru/company/otus/blog/331746/
# 2       https://habr.com/ru/company/otus/blog/331998/
# 3                    https://habr.com/ru/post/670668/
# 4                    https://habr.com/ru/post/556042/
# ..                                                ...
# 75                   https://habr.com/ru/post/501338/
# 76    https://habr.com/ru/company/yandex/blog/501924/
# 77                   https://habr.com/ru/post/514526/
# 78  https://habr.com/ru/company/skillfactory/blog/...
# 79  https://habr.com/ru/company/skillfactory/blog/...
#
#                                                  text num of likes
# 0   14 декабря в Нетологии пройдёт вебинар, посвящ...            4
# 1   Если Вы только начинаете свой путь знакомства ...            8
# 2   Первая часть статьи была опубликована тут.\n\n...           15
# 3   Доброго времени суток! Меня зовут Алексей. Сей...            5
# 4   Пост №3 для начинающих посвящен генерированию ...            0
# ..                                                ...          ...
# 75  Оглавление\n\n1 часть\n2 часть\n\nВведение\n\n...           28
# 76  Всем привет, меня зовут Фёдор Индукаев, я рабо...           41
# 77  Привет, Хабр. \nВ данной статье хотелось бы за...            5
# 78  Сегодня, в преддверии старта нового потока кур...           18
# 79  Если вам хочется попробовать все фичи великоле...           24
#
# [80 rows x 5 columns]

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой [Google Colab](https://colab.research.google.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
